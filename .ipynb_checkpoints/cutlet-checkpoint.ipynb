# %%
import glob
import math
import time
import datetime
import cv2
import numpy as np
import imutils
import bimpy
from PIL import ImageFont, ImageDraw, Image
from find_circles import find_circles
from threading import Thread
from sklearn.metrics import r2_score

# %%
def auto_canny(frame,sigma=0.33):
    v = np.median(frame)
    lower = int(max(0, (1.0 - sigma) * v))
    upper = int(min(255, (1.0 + sigma) * v))
    return cv2.Canny(frame,lower,upper)

def distf(a,b):
    return math.sqrt(math.pow(a[0]-b[0],2)+math.pow(a[1]-b[1],2))

def move_to_storage():
    pass

def robot_turn(x,y):
    pass

def clean_robot_plate(x,y):
    pass

def add_cutlet(x,y,r):
    global table
    global frying_time
    global order_number
    kotleta = {
    "pos": (x,y,r),
    "order": order_number,
    "fry":[
        [0,frying_time],
    ],
    "status": 0.01,
    "turning":False,
    "r2score":0
   
    }
        
    table = np.append(table, kotleta)
    order_number += 1
    
    
    
def turn_cutlet(katleta):
    global frying_time
    fry = katleta['fry']
    if len(fry)<4:
        if fry[-1][0] == 1:
            fry.append([0,frying_time])
        else:
            fry.append([1,frying_time])
    
        katleta['turning'] = True
        time.sleep(20)
        #robot_turn(x,y)
        katleta['turning'] = False
        circles = find_circles(frame) 
        for x,y,r in circles:
            found = False
            for k in table:
                
                x_t,y_t,r_t = k['pos']
                
                if distf((x,y),(x_t+r*2,y_t))<150:
                    k['pos'] = (x,y,r)
                    found = True
                    break
            if not found:
                add_cutlet(x,y,r)                
    
    else:
        move_to_storage()

# %%
cap = cv2.VideoCapture("http://192.168.1.65:8080/video")#"http://192.168.1.65:8080/video"
ret, frame = cap.read()
fourcc = cv2.VideoWriter_fourcc(*'MP4V')    
ret, frame = cap.read() 
v_out = cv2.VideoWriter('interface_thread {}.mp4'.format(time.time()),fourcc, 5.0, (frame.shape[1],frame.shape[0]),3)


order_number = 1000
frying_time = 0.0
all_time = 40.0*4


#инициализация bimpy
ctx = bimpy.Context()
ctx.init(1270, 720, "Cutlet")
#шрифт для PIL
font = ImageFont.truetype("arial.ttf", 32)

#создаем стол
table = np.array([])

#первый поиск
circles = find_circles(frame) 

for x, y, r in circles:
    add_cutlet(x,y,r)
    print(r)
        
        

while(not ctx.should_close()):
    #получаем кадр, преобразовываем в PIL 
    key = cv2.waitKey(1)
    ret, frame = cap.read()
    h,w = frame.shape[:2]
    pil_im = Image.fromarray(frame)
    draw = ImageDraw.Draw(pil_im)
   
    #создаем фрейм bimby 
    ctx.new_frame()
    if bimpy.begin("Cutlet", flags=(bimpy.WindowFlags.AlwaysAutoResize | bimpy.WindowFlags.NoTitleBar)): 
        #выводим готовящиеся котлеты на столе
        
        for kotleta in table:
            
            if kotleta['status']<1 and not kotleta['turning']:
                status = kotleta['status']
                x,y,r = kotleta['pos']
                fry = kotleta['fry']
                order = "Заказ №" + str(kotleta['order'])
                score = kotleta['r2score']
                
                
                indent = 0
                turn_text_size_h=0
                for f in fry:
                    turn_text_size_w=0
                    
                    time_text = " {}:{} ".format(int(f[1]/60), int(f[1]%60) if f[1]%60>9 else '0'+ str(int(f[1]%60)))
                    turn_text_size_w += draw.textsize(time_text, font=font)[0] + draw.textsize(order, font=font)[0]
                    turn_text_size_h += draw.textsize(order, font=font)[1]
                    
                    side = "Сторона А " if f[0] == 0 else "Сторона Б "
                    draw.text((x+r+30, y-r-10+indent), side , font=font) #+time_text
                    indent += 30
                    
                
                #отрисовываем
                draw.rectangle((x-r-10, y-r-10, x+r+10, y+r+10), outline="green", width=5) #котлета
                    
                draw.rectangle((x-r-10, y+r+15, x+r+10, y+r+55), outline="green", width=5) #статус (пустой)
                draw.rectangle((x-r-10, y+r+15, x-r+(status*r*2), y+r+55), outline="green", fill="green") #статус 
                kotleta['status']+= 1/all_time
                
                draw.rectangle((x-draw.textsize(side, font=font)[0]/2-5, y-20, x+draw.textsize(side, font=font)[0]/2+5, y+50), outline="white", fill="white")
                draw.text((x-draw.textsize(side, font=font)[0]/2,y-20), side +"\n     "+ time_text,(0,0,0), font=font) #время на котлете
                #draw.text((x-15, y+r+20), "{}:{} ".format(int(timer/60), int(t) if t>9 else '0'+ str(int(t)) ), font=font)
                    
                draw.rectangle((x-r-10, y-r-60, x+r+10, y-r-15), outline="green", width=5) #область заказа
                draw.rectangle((x+r+15, y-r-10, x+r+turn_text_size_w+10, y-r+turn_text_size_h+10), outline="green", width=5) #переворачивания
                   
                draw.text((x-r,y-r-60), order, font=font) #заказ
                
                fry_size = len(fry)
                if (fry_size==4 and fry[-1][1]>=40.0):
                    top = draw.textsize(time_text, font=font)[1]*5
                    draw.text((x+r+30, y-r-10+top), "Котлета готова!" , font=font)       
                else:
                    f[1]+=1
                    
                if fry[-1][1]>=40.0:
                    thread = Thread(target=turn_cutlet, args=(kotleta,))
                    thread.start()
                    


                circles = find_circles(frame) 



                for x,y,r in circles:
                    if 130<r<160:
                        found = False
                        for k in table:

                            x_t,y_t,r_t = k['pos']

                            if distf((x,y),(x_t,y_t))<150:
                                score = r2_score((x,y,r),(x_t,y_t,r_t))
                                k['r2score'] = f" {score:.3f}" 

                                if score > 0.98:
                                    found = True
                                    break

                                k['pos'] = (x,y,r)
                                found = True
                                break
                        if not found:
                            add_cutlet(x,y,r) 
        
        v_out.write(np.array(pil_im))
        #изменяем размер и палитру
        resized = cv2.resize(np.array(pil_im)[:, :, ::-1],(int(w/2),int(h/2)))
        im = bimpy.Image(resized)
       
        #выводим на экран
        bimpy.image(im)
          
    bimpy.end()
    ctx.render()
    del draw
   
    time.sleep(1)
    
    
    if key == ord('q') or ret == False:
        break 

v_out.release()
#if isinstance(v_out, type(None)) == False: v_out.release()
#cv2.destroyAllWindows()
# Out:
# 162
# 141
# 142
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ad39de349d69> in <module>
#      95
#      96
# ---> 97                 circles = find_circles(frame)
#      98
#      99
#
# ~/Documents/cutlet_find/find_circles.py in find_circles(img, max_mean, circle_mean)
#      14     """
#      15
# ---> 16     canny = auto_canny(img)
#      17     canny2 = cv2.dilate(canny, np.ones((3, 3), np.uint8))
#      18     contours, _ = cv2.findContours(canny2, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#
# ~/Documents/cutlet_find/find_circles.py in auto_canny(frame, sigma)
#       3
#       4 def auto_canny(frame,sigma=0.33):
# ----> 5     v = np.median(frame)
#       6     lower = int(max(0, (1.0 - sigma) * v))
#       7     upper = int(min(255, (1.0 + sigma) * v))
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3495     """
#    3496     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3497                     overwrite_input=overwrite_input)
#    3498     if keepdims:
#    3499         return r.reshape(k)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3403         keepdim = (1,) * a.ndim
#    3404
# -> 3405     r = func(a, **kwargs)
#    3406     return r, keepdim
#    3407
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _median(a, axis, out, overwrite_input)
#    3528             part = a
#    3529     else:
# -> 3530         part = partition(a, kth, axis=axis)
#    3531
#    3532     if part.shape == ():
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in partition(a, kth, axis, kind, order)
#     732     else:
#     733         a = asanyarray(a).copy(order="K")
# --> 734     a.partition(kth, axis=axis, kind=kind, order=order)
#     735     return a
#     736
#
# KeyboardInterrupt:

# %%
v_out.release()
